# %%
# Import python packages
import streamlit as st
import pandas as pd
from snowflake.snowpark.functions import col
from tabulate import tabulate

# We can also use Snowpark for our analyses!
from snowflake.snowpark.context import get_active_session
session = get_active_session()

# %%
select * from UBER10K_ANALYSIS;

# %%
df_table = session.table("UBER10K_ANALYSIS").select(col("SWOT"))
df_table.show()

# %%
pd.set_option('display.max_rows', None)
pd = df_table.to_pandas()

# %%
print(pd.to_markdown())

# %%
df_table2 = session.table("UBER10K_ANALYSIS").select(col("Current Ranking")).to_pandas()

print(df_table2.to_markdown())
